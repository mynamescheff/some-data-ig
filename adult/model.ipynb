# %%
"""# Read the .data file
with open("adult.data", "r") as infile:
    data = infile.read()

# Replace double commas with a single comma and remove spaces after commas
data = data.replace(",,", ",").replace(", ", ",")

# Save as a .csv file
with open("adult.csv", "w") as outfile:
    outfile.write(data)

print("Conversion completed. Data saved to adult.csv")"""
# Out:
# '# Read the .data file\nwith open("adult.data", "r") as infile:\n    data = infile.read()\n\n# Replace double commas with a single comma and remove spaces after commas\ndata = data.replace(",,", ",").replace(", ", ",")\n\n# Save as a .csv file\nwith open("adult.csv", "w") as outfile:\n    outfile.write(data)\n\nprint("Conversion completed. Data saved to adult.csv")'

# %%
import pandas as pd

df = pd.read_csv("adult.csv")
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
#amount of null values
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
#visualize the data
import matplotlib.pyplot as plt
import seaborn as sns

sns.pairplot(df)

# %%
#data distribution of each column
df.hist(bins=30, figsize=(20,15))
plt.show()

# %%
#correlation matrix
corr_matrix = df.corr()
plt.figure(figsize=(20,15))
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
#make a list of columns without numerical values
non_numerical_cols = df.select_dtypes(exclude=['int64', 'float64']).columns.tolist()
non_numerical_cols
# Out:
# ['workclass',
#  'education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native-country',
#  'income']

# %%
#check for number of unique values in each column of categorical data
for col in non_numerical_cols:
    print(col, df[col].nunique())
# Out:
# workclass 9
# education 16
# marital-status 7
# occupation 15
# relationship 6
# race 5
# sex 2
# native-country 42
# income 2

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
#drop some columns
df = df.drop(['fnlwgt', 'native-country'], axis=1)
df.head()
# Out:
#    age         workclass  education  education-num      marital-status  \
# 0   39         State-gov  Bachelors             13       Never-married
# 1   50  Self-emp-not-inc  Bachelors             13  Married-civ-spouse
# 2   38           Private    HS-grad              9            Divorced
# 3   53           Private       11th              7  Married-civ-spouse
# 4   28           Private  Bachelors             13  Married-civ-spouse
#
#           occupation   relationship   race     sex  capital-gain  \
# 0       Adm-clerical  Not-in-family  White    Male          2174
# 1    Exec-managerial        Husband  White    Male             0
# 2  Handlers-cleaners  Not-in-family  White    Male             0
# 3  Handlers-cleaners        Husband  Black    Male             0
# 4     Prof-specialty           Wife  Black  Female             0
#
#    capital-loss  hours-per-week income
# 0             0              40  <=50K
# 1             0              13  <=50K
# ...

# %%
# Create a dictionary that maps the values in the "education-num" column to the corresponding values in the "education" column
education_dict = df.set_index('education-num')['education'].to_dict()

# Remove the "education" column from the dataframe
df = df.drop('education', axis=1)
df.head()
# Out:
#    age         workclass  education-num      marital-status  \
# 0   39         State-gov             13       Never-married
# 1   50  Self-emp-not-inc             13  Married-civ-spouse
# 2   38           Private              9            Divorced
# 3   53           Private              7  Married-civ-spouse
# 4   28           Private             13  Married-civ-spouse
#
#           occupation   relationship   race     sex  capital-gain  \
# 0       Adm-clerical  Not-in-family  White    Male          2174
# 1    Exec-managerial        Husband  White    Male             0
# 2  Handlers-cleaners  Not-in-family  White    Male             0
# 3  Handlers-cleaners        Husband  Black    Male             0
# 4     Prof-specialty           Wife  Black  Female             0
#
#    capital-loss  hours-per-week income
# 0             0              40  <=50K
# 1             0              13  <=50K
# 2             0              40  <=50K
# 3             0              40  <=50K
# ...

# %%
#sort education_dict from lowest to highest numbers
education_dict
# Out:
# {13: 'Bachelors',
#  9: 'HS-grad',
#  7: '11th',
#  14: 'Masters',
#  5: '9th',
#  10: 'Some-college',
#  12: 'Assoc-acdm',
#  11: 'Assoc-voc',
#  4: '7th-8th',
#  16: 'Doctorate',
#  15: 'Prof-school',
#  3: '5th-6th',
#  6: '10th',
#  2: '1st-4th',
#  1: 'Preschool',
#  8: '12th'}

# %%
#graph of distribution of capital-gain column

plt.figure(figsize=(20,15))
sns.distplot(df['capital-gain'])
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_17556\2145043980.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['capital-gain'])

# %%
#graph of distribution of capital-loss column

plt.figure(figsize=(20,15))
sns.distplot(df['capital-loss'])
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_17556\84615817.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['capital-loss'])

# %%
#list of categorical columns
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()
categorical_cols
# Out:
# ['workclass',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'income']

# %%
#copy of dataframe for preprocessing
df2 = df.copy()

# %%
df3 = df.copy()

# %%
#label encoding for categorical columns in df2
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in categorical_cols:
    df2[col] = le.fit_transform(df2[col])
df2.head()
# Out:
#    age  workclass  education-num  marital-status  occupation  relationship  \
# 0   39          7             13               4           1             1
# 1   50          6             13               2           4             0
# 2   38          4              9               0           6             1
# 3   53          4              7               2           6             0
# 4   28          4             13               2          10             5
#
#    race  sex  capital-gain  capital-loss  hours-per-week  income
# 0     4    1          2174             0              40       0
# 1     4    1             0             0              13       0
# 2     4    1             0             0              40       0
# 3     2    1             0             0              40       0
# 4     2    0             0             0              40       0

# %%
#one hot encoding for categorical columns in df3 except for the target column
df3 = pd.get_dummies(df3, columns=categorical_cols[:-1])
df3.head()
# Out:
#    age  education-num  capital-gain  capital-loss  hours-per-week income  \
# 0   39             13          2174             0              40  <=50K
# 1   50             13             0             0              13  <=50K
# 2   38              9             0             0              40  <=50K
# 3   53              7             0             0              40  <=50K
# 4   28             13             0             0              40  <=50K
#
#    workclass_?  workclass_Federal-gov  workclass_Local-gov  \
# 0            0                      0                    0
# 1            0                      0                    0
# 2            0                      0                    0
# 3            0                      0                    0
# 4            0                      0                    0
#
#    workclass_Never-worked  ...  relationship_Own-child  \
# 0                       0  ...                       0
# 1                       0  ...                       0
# ...

# %%
#splitting the data into training and testing sets in df2
from sklearn.model_selection import train_test_split
X = df2.drop('income', axis=1)
y = df2['income']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor ,GradientBoostingRegressor,AdaBoostRegressor
from sklearn.svm import SVR,LinearSVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import xgboost as xgb
from catboost import CatBoostRegressor
import lightgbm as lgb
from sklearn.linear_model import LinearRegression

models = {
    'Linear Regression': LinearRegression(),
    'Decision Tree': DecisionTreeRegressor(),
    'Random Forest': RandomForestRegressor(),
    'SVR': SVR(),
    'XGBoost': xgb.XGBRegressor(),
    'LightGBM': lgb.LGBMRegressor(),
    'Gradient Boosting Regressor' : GradientBoostingRegressor(),
    'ADA Boost' : AdaBoostRegressor(),
    'K Neighbors Regressor' : KNeighborsRegressor(),
    'Linear SVR' : LinearSVR(),
    'Cat Boost Regressor' : CatBoostRegressor(),
}

# %%
Name = ['Linear Regression','Decision Tree','Random Forest','SVR','XGBoost','LightGBM','Gradient Boosting Regressor' ,'ADA Boost' ,'K Neighbors Regressor','Linear SVR','Cat Boost Regressor']
accuracy = []
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    print(f"Results for {name}:")
    print("Mean Squared Error (MSE):", mse)
    print("Mean Absolute Error (MAE):", mae)
    print("R-squared Score:", r2)
    accuracy.append(r2)
    print()
# Out:
# Results for Linear Regression:
# Mean Squared Error (MSE): 0.13256371448646617
# Mean Absolute Error (MAE): 0.29285910100654083
# R-squared Score: 0.26607266649510397
#
# Results for Decision Tree:
# Mean Squared Error (MSE): 0.1681693618625245
# Mean Absolute Error (MAE): 0.179711618792281
# R-squared Score: 0.06894513474436992
#
# Results for Random Forest:
# Mean Squared Error (MSE): 0.10590501288423572
# Mean Absolute Error (MAE): 0.18584223567841784
# R-squared Score: 0.41366622071483883
#
# Results for SVR:
# Mean Squared Error (MSE): 0.15745313693925367
# Mean Absolute Error (MAE): 0.25130763190742156
# R-squared Score: 0.12827457050771252
#
# Results for XGBoost:
# Mean Squared Error (MSE): 0.08919331122429072
# Mean Absolute Error (MAE): 0.1848479061077387
# R-squared Score: 0.5061890855510152
#
# Results for LightGBM:
# Mean Squared Error (MSE): 0.08742561149459882
# Mean Absolute Error (MAE): 0.18261962538487786
# R-squared Score: 0.515975799464969
#
# ...

# %%
accuracy
# Out:
# [0.26607266649510397,
#  0.06894513474436992,
#  0.41366622071483883,
#  0.12827457050771252,
#  0.5061890855510152,
#  0.515975799464969,
#  0.48950132921773637,
#  0.3093816895236635,
#  0.3927883023582289,
#  -0.10700815436477829,
#  0.524559418108232]

# %%
data = pd.DataFrame({"Names": Name, "Accuracies": accuracy})

sns.set(style="ticks")
plt.figure(figsize=(8, 6))

sns.barplot(x="Accuracies", y="Names", data=data, color="r")

plt.xlabel("Accuracy")
plt.ylabel("Model Names")
plt.title("Model Accuracies")

plt.show()

# %%
#create a function that checks for the best amount of neighbors
#categorical, specific class, binary classification with two classes

from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

def check_neighbors(X_train, y_train, X_test, y_test, k):
    best_score = 0
    best_k = 0
    scores = []
    neighbors = []
    
    for i in range(1, k):
        knn = KNeighborsClassifier(n_neighbors=i)
        knn.fit(X_train, y_train)
        score = knn.score(X_test, y_test)
        
        scores.append(score)
        neighbors.append(i)
        
        if score > best_score:
            best_score = score
            best_k = i
            
    return best_k, best_score, neighbors, scores

best_k, best_score, neighbors, scores = check_neighbors(X_train, y_train, X_test, y_test, 100)
print(f"The best value for k neighbors in classification is: {best_k} with an accuracy of {best_score:.4f}")

plt.plot(neighbors, scores)
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy Score')
plt.title('Accuracy Score for Different Number of Neighbors')
plt.show()
# Out:
# The best value for k neighbors in classification is: 22 with an accuracy of 0.8577

# %%
#change string from the income column to a numerical value, <=50K = 0, >50K = 1
df3['income'] = df3['income'].replace({'<=50K': 0, '>50K': 1})

# %%
#splitting the data into training and testing sets in df3
from sklearn.model_selection import train_test_split
X2 = df3.drop('income', axis=1)
y2 = df3['income']

X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.2, random_state=101)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor ,GradientBoostingRegressor,AdaBoostRegressor
from sklearn.svm import SVR,LinearSVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import xgboost as xgb
from catboost import CatBoostRegressor
import lightgbm as lgb
from sklearn.linear_model import LinearRegression

models2 = {
    'Linear Regression': LinearRegression(),
    'Decision Tree': DecisionTreeRegressor(),
    'Random Forest': RandomForestRegressor(),
    'SVR': SVR(),
    'XGBoost': xgb.XGBRegressor(),
    'LightGBM': lgb.LGBMRegressor(),
    'Gradient Boosting Regressor' : GradientBoostingRegressor(),
    'ADA Boost' : AdaBoostRegressor(),
    'K Neighbors Regressor' : KNeighborsRegressor(),
    'Linear SVR' : LinearSVR(),
    'Cat Boost Regressor' : CatBoostRegressor(),
}

# %%
Name2 = ['Linear Regression','Decision Tree','Random Forest','SVR','XGBoost','LightGBM','Gradient Boosting Regressor' ,'ADA Boost' ,'K Neighbors Regressor','Linear SVR','Cat Boost Regressor']
accuracy2 = []
for namee, model2 in models2.items():
    model2.fit(X_train2, y_train2)
    y_pred2 = model2.predict(X_test2)
    
    mse2 = mean_squared_error(y_test2, y_pred2)
    mae2 = mean_absolute_error(y_test2, y_pred2)
    r22 = r2_score(y_test2, y_pred2)
    
    print(f"Results for {namee}:")
    print("Mean Squared Error (MSE):", mse2)
    print("Mean Absolute Error (MAE):", mae2)
    print("R-squared Score:", r22)
    accuracy2.append(r22)
    print()
# Out:
# Results for Linear Regression:
# Mean Squared Error (MSE): 0.11531537821060331
# Mean Absolute Error (MAE): 0.2644846882144056
# R-squared Score: 0.36156656163359746
#
# Results for Decision Tree:
# Mean Squared Error (MSE): 0.16140856113826038
# Mean Absolute Error (MAE): 0.17371265643544614
# R-squared Score: 0.10637571269052215
#
# Results for Random Forest:
# Mean Squared Error (MSE): 0.10386369135249156
# Mean Absolute Error (MAE): 0.1815746389424711
# R-squared Score: 0.4249678176444577
#
# Results for SVR:
# Mean Squared Error (MSE): 0.15748446331006472
# Mean Absolute Error (MAE): 0.2510418332164538
# R-squared Score: 0.1281011348138894
#
# Results for XGBoost:
# Mean Squared Error (MSE): 0.08897431365005642
# Mean Absolute Error (MAE): 0.18282911552647535
# R-squared Score: 0.5074015463388292
#
# Results for LightGBM:
# Mean Squared Error (MSE): 0.08687960048942604
# Mean Absolute Error (MAE): 0.18057053692790834
# R-squared Score: 0.5189987413208392
#
# ...

# %%
accuracy2
# Out:
# [0.36156656163359746,
#  0.10637571269052215,
#  0.4249678176444577,
#  0.1281011348138894,
#  0.5074015463388292,
#  0.5189987413208392,
#  0.4881755551588952,
#  0.34806648244038296,
#  0.40598116486718894,
#  -1.3364675604887655,
#  0.5229471204656275]

# %%
data2 = pd.DataFrame({"Names": Name2, "Accuracies": accuracy2})

sns.set(style="ticks")
plt.figure(figsize=(8, 6))

sns.barplot(x="Accuracies", y="Names", data=data, color="r")

plt.xlabel("Accuracy")
plt.ylabel("Model Names")
plt.title("Model Accuracies")

plt.show()

# %%
#create a function that checks for the best amount of neighbors
#categorical, specific class, binary classification with two classes

from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

def check_neighbors(X_train2, y_train2, X_test2, y_test2, k):
    best_score2 = 0
    best_k2 = 0
    scores2 = []
    neighbors2 = []
    
    for i in range(1, k):
        knn = KNeighborsClassifier(n_neighbors=i)
        knn.fit(X_train2, y_train2)
        score2 = knn.score(X_test2, y_test2)
        
        scores2.append(score2)
        neighbors2.append(i)
        
        if score2 > best_score2:
            best_score2 = score2
            best_k2 = i
            
    return best_k2, best_score2, neighbors2, scores2

best_k2, best_score2, neighbors2, scores2 = check_neighbors(X_train2, y_train2, X_test2, y_test2, 100)
print(f"The best value for k neighbors in classification is: {best_k2} with an accuracy of {best_score2:.4f}")

plt.plot(neighbors2, scores2)
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy Score')
plt.title('Accuracy Score for Different Number of Neighbors')
plt.show()
# Out:
# The best value for k neighbors in classification is: 6 with an accuracy of 0.8600
